# %%
import os
from os.path import join
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = os.getenv('HOME')+'/aiffel/kaggle_covid19/data'

Case_path = join(data_dir, 'Case.csv')
PatientInfo_path = join(data_dir, 'PatientInfo.csv')
Policy_path = join(data_dir, 'Policy.csv')
Region_path = join(data_dir, 'Region.csv')
SearchTrend_path = join(data_dir, 'SearchTrend.csv')
SeoulFloating_path = join(data_dir, 'SeoulFloating.csv')
Time_path = join(data_dir, 'Time.csv')
TimeAge_path = join(data_dir, 'TimeAge.csv')
TimeGender_path = join(data_dir, 'TimeGender.csv')
TimeProvince_path = join(data_dir, 'TimeProvince.csv')
Weather_path = join(data_dir, 'Weather.csv')

Case = pd.read_csv(Case_path)
PatientInfo = pd.read_csv(PatientInfo_path)
Policy = pd.read_csv(Policy_path)
Region = pd.read_csv(Region_path)
SearchTrend = pd.read_csv(SearchTrend_path)
SeoulFloating = pd.read_csv(SeoulFloating_path)
Time = pd.read_csv(Time_path)
TimeAge = pd.read_csv(TimeAge_path)
TimeGender = pd.read_csv(TimeGender_path)
TimeAge = pd.read_csv(TimeAge_path)
TimeProvince = pd.read_csv(TimeProvince_path)
Weather = pd.read_csv(Weather_path)

Case
# Out:
#       case_id          province             city  group  \
# 0     1000001             Seoul       Yongsan-gu   True
# 1     1000002             Seoul        Gwanak-gu   True
# 2     1000003             Seoul          Guro-gu   True
# 3     1000004             Seoul     Yangcheon-gu   True
# 4     1000005             Seoul        Dobong-gu   True
# ..        ...               ...              ...    ...
# 169   6100012  Gyeongsangnam-do                -  False
# 170   7000001           Jeju-do                -  False
# 171   7000002           Jeju-do                -  False
# 172   7000003           Jeju-do                -  False
# 173   7000004           Jeju-do  from other city   True
#
#                   infection_case  confirmed   latitude   longitude
# 0                  Itaewon Clubs        139  37.538621  126.992652
# 1                        Richway        119   37.48208  126.901384
# 2            Guro-gu Call Center         95  37.508163  126.884387
# ...

# %%
PatientInfo.head()
# Out:
#    patient_id     sex  age country province         city  \
# 0  1000000001    male  50s   Korea    Seoul   Gangseo-gu
# 1  1000000002    male  30s   Korea    Seoul  Jungnang-gu
# 2  1000000003    male  50s   Korea    Seoul    Jongno-gu
# 3  1000000004    male  20s   Korea    Seoul      Mapo-gu
# 4  1000000005  female  20s   Korea    Seoul  Seongbuk-gu
#
#          infection_case infected_by contact_number symptom_onset_date  \
# 0       overseas inflow         NaN             75         2020-01-22
# 1       overseas inflow         NaN             31                NaN
# 2  contact with patient  2002000001             17                NaN
# 3       overseas inflow         NaN              9         2020-01-26
# 4  contact with patient  1000000002              2                NaN
#
#   confirmed_date released_date deceased_date     state
# 0     2020-01-23    2020-02-05           NaN  released
# 1     2020-01-30    2020-03-02           NaN  released
# ...

# %%
Policy
# Out:
#     policy_id country            type                              gov_policy  \
# 0           1   Korea           Alert          Infectious Disease Alert Level
# 1           2   Korea           Alert          Infectious Disease Alert Level
# 2           3   Korea           Alert          Infectious Disease Alert Level
# 3           4   Korea           Alert          Infectious Disease Alert Level
# 4           5   Korea     Immigration           Special Immigration Procedure
# ..        ...     ...             ...                                     ...
# 56         57   Korea  Transformation                        Logistics center
# 57         58   Korea  Transformation                        Wearing of masks
# 58         59   Korea  Transformation                        Wearing of masks
# 59         60   Korea      Technology          KI-Pass: Korea Internet - Pass
# 60         61   Korea          Health  Extends Tightened Quarantine Measures
#
# ...

# %%
Region.head()
# Out:
#     code province         city   latitude   longitude  \
# 0  10000    Seoul        Seoul  37.566953  126.977977
# 1  10010    Seoul   Gangnam-gu  37.518421  127.047222
# 2  10020    Seoul  Gangdong-gu  37.530492  127.123837
# 3  10030    Seoul   Gangbuk-gu  37.639938  127.025508
# 4  10040    Seoul   Gangseo-gu  37.551166  126.849506
#
#    elementary_school_count  kindergarten_count  university_count  \
# 0                      607                 830                48
# 1                       33                  38                 0
# 2                       27                  32                 0
# 3                       14                  21                 0
# 4                       36                  56                 1
#
#    academy_ratio  elderly_population_ratio  elderly_alone_ratio  \
# 0           1.44                     15.38                  5.8
# 1           4.18                     13.17                  4.3
# ...

# %%
SearchTrend
# Out:
#             date     cold      flu  pneumonia  coronavirus
# 0     2016-01-01  0.11663  0.05590    0.15726      0.00736
# 1     2016-01-02  0.13372  0.17135    0.20826      0.00890
# 2     2016-01-03  0.14917  0.22317    0.19326      0.00845
# 3     2016-01-04  0.17463  0.18626    0.29008      0.01145
# 4     2016-01-05  0.17226  0.15072    0.24562      0.01381
# ...          ...      ...      ...        ...          ...
# 1637  2020-06-25  0.12072  0.04190    0.11936      2.16993
# 1638  2020-06-26  0.11381  0.03027    0.11317      2.15139
# 1639  2020-06-27  0.10554  0.02136    0.08354      1.96848
# 1640  2020-06-28  0.12563  0.02872    0.08072      2.19720
# 1641  2020-06-29  0.14263  0.04308    0.11254      2.41501
#
# [1642 rows x 5 columns]

# %%
SearchTrend.loc[(SearchTrend.date=='2020-01-20')]
# Out:
#             date     cold      flu  pneumonia  coronavirus
# 1480  2020-01-20  0.19217  0.70343    3.63716      20.6961

# %%
SearchTrend=SearchTrend.loc[1480:] #2020년 1월 20일 기록부터 추출
SearchTrend
# Out:
#             date     cold      flu  pneumonia  coronavirus
# 1480  2020-01-20  0.19217  0.70343    3.63716     20.69610
# 1481  2020-01-21  0.22462  0.59789    4.31987     35.33284
# 1482  2020-01-22  0.23808  0.56661    3.66416     29.74474
# 1483  2020-01-23  0.30308  0.55625    3.18035    100.00000
# 1484  2020-01-24  0.34689  0.40226    2.48156     86.11541
# ...          ...      ...      ...        ...          ...
# 1637  2020-06-25  0.12072  0.04190    0.11936      2.16993
# 1638  2020-06-26  0.11381  0.03027    0.11317      2.15139
# 1639  2020-06-27  0.10554  0.02136    0.08354      1.96848
# 1640  2020-06-28  0.12563  0.02872    0.08072      2.19720
# 1641  2020-06-29  0.14263  0.04308    0.11254      2.41501
#
# [162 rows x 5 columns]

# %%
SeoulFloating.head()
# Out:
#          date  hour  birth_year     sex province           city  fp_num
# 0  2020-01-01     0          20  female    Seoul      Dobong-gu   19140
# 1  2020-01-01     0          20    male    Seoul      Dobong-gu   19950
# 2  2020-01-01     0          20  female    Seoul  Dongdaemun-gu   25450
# 3  2020-01-01     0          20    male    Seoul  Dongdaemun-gu   27050
# 4  2020-01-01     0          20  female    Seoul     Dongjag-gu   28880

# %%
Time
# Out:
#            date  time     test  negative  confirmed  released  deceased
# 0    2020-01-20    16        1         0          1         0         0
# 1    2020-01-21    16        1         0          1         0         0
# 2    2020-01-22    16        4         3          1         0         0
# 3    2020-01-23    16       22        21          1         0         0
# 4    2020-01-24    16       27        25          2         0         0
# ..          ...   ...      ...       ...        ...       ...       ...
# 158  2020-06-26     0  1232315   1200885      12602     11172       282
# 159  2020-06-27     0  1243780   1211261      12653     11317       282
# 160  2020-06-28     0  1251695   1219975      12715     11364       282
# 161  2020-06-29     0  1259954   1228698      12757     11429       282
# 162  2020-06-30     0  1273766   1240157      12800     11537       282
#
# [163 rows x 7 columns]

# %%
TimeAge.head()
# Out:
#          date  time  age  confirmed  deceased
# 0  2020-03-02     0   0s         32         0
# 1  2020-03-02     0  10s        169         0
# 2  2020-03-02     0  20s       1235         0
# 3  2020-03-02     0  30s        506         1
# 4  2020-03-02     0  40s        633         1

# %%
TimeProvince.head()
# Out:
#          date  time province  confirmed  released  deceased
# 0  2020-01-20    16    Seoul          0         0         0
# 1  2020-01-20    16    Busan          0         0         0
# 2  2020-01-20    16    Daegu          0         0         0
# 3  2020-01-20    16  Incheon          1         0         0
# 4  2020-01-20    16  Gwangju          0         0         0

# %%
Weather
# Out:
#         code          province        date  avg_temp  min_temp  max_temp  \
# 0      10000             Seoul  2016-01-01       1.2      -3.3       4.0
# 1      11000             Busan  2016-01-01       5.3       1.1      10.9
# 2      12000             Daegu  2016-01-01       1.7      -4.0       8.0
# 3      13000           Gwangju  2016-01-01       3.2      -1.5       8.1
# 4      14000           Incheon  2016-01-01       3.1      -0.4       5.7
# ...      ...               ...         ...       ...       ...       ...
# 26266  50000      Jeollabuk-do  2020-06-29      22.0      19.7      26.5
# 26267  51000      Jeollanam-do  2020-06-29      21.9      20.0      24.0
# 26268  60000  Gyeongsangbuk-do  2020-06-29      20.4      17.4      24.5
# 26269  61000  Gyeongsangnam-do  2020-06-29      21.9      18.8      25.5
# 26270  70000           Jeju-do  2020-06-29      23.2      19.1      27.6
#
#        precipitation  max_wind_speed  most_wind_direction  \
# ...

# %%
Weather.loc[(Weather.date=='2020-01-20')]
# Out:
#         code           province        date  avg_temp  min_temp  max_temp  \
# 23679  10000              Seoul  2020-01-20       0.7      -3.3       5.5
# 23680  11000              Busan  2020-01-20       5.1       1.6       9.8
# 23681  12000              Daegu  2020-01-20       4.6       2.4       8.1
# 23682  13000            Gwangju  2020-01-20       4.0       1.2       7.9
# 23683  14000            Incheon  2020-01-20       1.2      -2.1       5.1
# 23684  15000            Daejeon  2020-01-20       3.4      -0.9       8.1
# 23685  16000              Ulsan  2020-01-20       4.3      -0.5       9.2
# 23686  20000        Gyeonggi-do  2020-01-20       1.2      -2.8       5.7
# 23687  30000         Gangwon-do  2020-01-20       3.7       1.1       7.5
# 23688  40000  Chungcheongbuk-do  2020-01-20       0.9      -2.9       5.8
# 23689  41000  Chungcheongnam-do  2020-01-20       1.7      -2.7       7.1
# 23690  50000       Jeollabuk-do  2020-01-20       3.5      -0.3       8.0
# ...

# %%
Weather_covid=Weather.loc[23679:] #2020년 1월 20일 기록부터 추출
Weather_covid
# Out:
#         code          province        date  avg_temp  min_temp  max_temp  \
# 23679  10000             Seoul  2020-01-20       0.7      -3.3       5.5
# 23680  11000             Busan  2020-01-20       5.1       1.6       9.8
# 23681  12000             Daegu  2020-01-20       4.6       2.4       8.1
# 23682  13000           Gwangju  2020-01-20       4.0       1.2       7.9
# 23683  14000           Incheon  2020-01-20       1.2      -2.1       5.1
# ...      ...               ...         ...       ...       ...       ...
# 26266  50000      Jeollabuk-do  2020-06-29      22.0      19.7      26.5
# 26267  51000      Jeollanam-do  2020-06-29      21.9      20.0      24.0
# 26268  60000  Gyeongsangbuk-do  2020-06-29      20.4      17.4      24.5
# 26269  61000  Gyeongsangnam-do  2020-06-29      21.9      18.8      25.5
# 26270  70000           Jeju-do  2020-06-29      23.2      19.1      27.6
#
#        precipitation  max_wind_speed  most_wind_direction  \
# ...

# %%
#날짜별 확진자 추이
df = Time


fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(df['date'],df['confirmed'],color='blue')

plt.xticks(rotation=90)

plt.title('Number of confirmed cases over time',fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 아이디어 1
# 20-30대 확진자가 어느 구에서 많이 나오는지?

# %%
young = ((PatientInfo.age=='20s')| (PatientInfo.age=='30s'))& (PatientInfo.province=='Seoul')
young_1= ((PatientInfo.age=='20s'))

# %%
PatientInfo[young]
# Out:
#      patient_id     sex  age country province          city  \
# 1    1000000002    male  30s   Korea    Seoul   Jungnang-gu
# 3    1000000004    male  20s   Korea    Seoul       Mapo-gu
# 4    1000000005  female  20s   Korea    Seoul   Seongbuk-gu
# 6    1000000007    male  20s   Korea    Seoul     Jongno-gu
# 7    1000000008    male  20s   Korea    Seoul           etc
# ..          ...     ...  ...     ...      ...           ...
# 699  1000000700    male  30s   Korea    Seoul  Yangcheon-gu
# 737  1000000738    male  20s   Korea    Seoul  Yangcheon-gu
# 738  1000000739    male  20s   Korea    Seoul  Yangcheon-gu
# 753  1000000754    male  30s   Korea    Seoul  Yangcheon-gu
# 880  1000000881    male  30s   Korea    Seoul    Gangseo-gu
#
#                       infection_case infected_by contact_number  \
# 1                    overseas inflow         NaN             31
# 3                    overseas inflow         NaN              9
# ...

# %%
PatientInfo[young_1]
# Out:
#       patient_id     sex  age country province         city  \
# 3     1000000004    male  20s   Korea    Seoul      Mapo-gu
# 4     1000000005  female  20s   Korea    Seoul  Seongbuk-gu
# 6     1000000007    male  20s   Korea    Seoul    Jongno-gu
# 7     1000000008    male  20s   Korea    Seoul          etc
# 11    1000000012    male  20s   Korea    Seoul          etc
# ...          ...     ...  ...     ...      ...          ...
# 5150  7000000005  female  20s   Korea  Jeju-do      Jeju-do
# 5152  7000000007  female  20s   Korea  Jeju-do      Jeju-do
# 5154  7000000009  female  20s   Korea  Jeju-do      Jeju-do
# 5155  7000000010  female  20s   Korea  Jeju-do      Jeju-do
# 5157  7000000012  female  20s   Korea  Jeju-do      Jeju-do
#
#             infection_case infected_by contact_number symptom_onset_date  \
# 3          overseas inflow         NaN              9         2020-01-26
# 4     contact with patient  1000000002              2                NaN
# ...

# %%
grouped_1 = PatientInfo[young_1].groupby(PatientInfo['province'])
grouped_1

# %%
grouped_1.size()
# Out:
# province
# Busan                 51
# Chungcheongbuk-do      8
# Chungcheongnam-do     19
# Daegu                 24
# Daejeon               19
# Gangwon-do            13
# Gwangju               11
# Gyeonggi-do          188
# Gyeongsangbuk-do     309
# Gyeongsangnam-do      31
# Incheon               17
# Jeju-do                7
# Jeollabuk-do          10
# Jeollanam-do           6
# Sejong                 1
# Seoul                165
# Ulsan                 20
# dtype: int64

# %%
grouped = PatientInfo[young].groupby(PatientInfo['city'])
grouped

# %%
grouped.size()
# Out:
# city
# Dobong-gu           4
# Dongdaemun-gu      19
# Dongjak-gu         14
# Eunpyeong-gu        9
# Gangbuk-gu          1
# Gangdong-gu         4
# Gangnam-gu         26
# Gangseo-gu         12
# Geumcheon-gu        3
# Guro-gu             5
# Gwanak-gu          17
# Gwangjin-gu         6
# Jongno-gu           5
# Jung-gu             2
# Jungnang-gu         9
# Mapo-gu            12
# Nowon-gu            8
# Seocho-gu          18
# Seodaemun-gu       10
# Seongbuk-gu        11
# Seongdong-gu        2
# Songpa-gu          26
# Yangcheon-gu       10
# Yeongdeungpo-gu     8
# Yongsan-gu          8
# etc                16
# dtype: int64

# %%
result= pd.DataFrame(grouped.size(), columns=['number'])
result
# Out:
#                  number
# city
# Dobong-gu             4
# Dongdaemun-gu        19
# Dongjak-gu           14
# Eunpyeong-gu          9
# Gangbuk-gu            1
# Gangdong-gu           4
# Gangnam-gu           26
# Gangseo-gu           12
# Geumcheon-gu          3
# Guro-gu               5
# Gwanak-gu            17
# Gwangjin-gu           6
# Jongno-gu             5
# Jung-gu               2
# Jungnang-gu           9
# Mapo-gu              12
# Nowon-gu              8
# Seocho-gu            18
# Seodaemun-gu         10
# Seongbuk-gu          11
# Seongdong-gu          2
# Songpa-gu            26
# Yangcheon-gu         10
# Yeongdeungpo-gu       8
# Yongsan-gu            8
# etc                  16

# %%
result.columns
# Out:
# Index(['number'], dtype='object')

# %%
result.index
# Out:
# Index(['Dobong-gu', 'Dongdaemun-gu', 'Dongjak-gu', 'Eunpyeong-gu',
#        'Gangbuk-gu', 'Gangdong-gu', 'Gangnam-gu', 'Gangseo-gu', 'Geumcheon-gu',
#        'Guro-gu', 'Gwanak-gu', 'Gwangjin-gu', 'Jongno-gu', 'Jung-gu',
#        'Jungnang-gu', 'Mapo-gu', 'Nowon-gu', 'Seocho-gu', 'Seodaemun-gu',
#        'Seongbuk-gu', 'Seongdong-gu', 'Songpa-gu', 'Yangcheon-gu',
#        'Yeongdeungpo-gu', 'Yongsan-gu', 'etc'],
#       dtype='object', name='city')

# %%
sorted = result.sort_values(by='number', ascending=True)

# %%
sorted
# Out:
#                  number
# city
# Gangbuk-gu            1
# Seongdong-gu          2
# Jung-gu               2
# Geumcheon-gu          3
# Dobong-gu             4
# Gangdong-gu           4
# Guro-gu               5
# Jongno-gu             5
# Gwangjin-gu           6
# Nowon-gu              8
# Yeongdeungpo-gu       8
# Yongsan-gu            8
# Eunpyeong-gu          9
# Jungnang-gu           9
# Yangcheon-gu         10
# Seodaemun-gu         10
# Seongbuk-gu          11
# Mapo-gu              12
# Gangseo-gu           12
# Dongjak-gu           14
# etc                  16
# Gwanak-gu            17
# Seocho-gu            18
# Dongdaemun-gu        19
# Songpa-gu            26
# Gangnam-gu           26

# %%
sorted.plot(kind = "barh",color='r', alpha=0.5, figsize=(10, 10))
# Out:
# <AxesSubplot:ylabel='city'>

# %% [markdown]
# ## 아이디어 2
# 실제로 음식점에서 많이 나오는지?
# 관광지나 헬스장 등의 장소에서
# 어디가 가장 많이 확진자가 나올까??

# %% [markdown]
# ## 아이디어 3
# 확진자 수도 중요하지만, 금일 선별진료소에서 검사를 받았고
# 그 결과적으로 몇 명의 확진자가 나왔는가?
# (+ a)일별 확진자 수가 아닌, 일별 test를 한 인원 수와 양성반응을 보인 사람의 비율 - 단순히 많아보이는 거일 수도 있고, 적어보일 수 있으므로

# %% [markdown]
# ## 아이디어 4
# 연령별로 확진자 통계를 내보고
# 중증 / 치사 등의 비율을 수치화??

# %% [markdown]
# ## 아이디어 5
# 지금까지 연령별로 코로나 확진자 누적을 해보고, 동선을 시각화?? (정부에서 조심하라고 한 곳을 갔는가? 가지 않았는가?) 등을 알아보는 것

# %% [markdown]
# ## 아이디어 6
# 온도에 따라서 코로나 바이러스가 퍼지는 정도가 달라지는 지 알아봅시다
# 온도/ 날씨/ 확진자 수 데이터 활용

# %%
Weather_covid
# Out:
#         code          province        date  avg_temp  min_temp  max_temp  \
# 23679  10000             Seoul  2020-01-20       0.7      -3.3       5.5
# 23680  11000             Busan  2020-01-20       5.1       1.6       9.8
# 23681  12000             Daegu  2020-01-20       4.6       2.4       8.1
# 23682  13000           Gwangju  2020-01-20       4.0       1.2       7.9
# 23683  14000           Incheon  2020-01-20       1.2      -2.1       5.1
# ...      ...               ...         ...       ...       ...       ...
# 26266  50000      Jeollabuk-do  2020-06-29      22.0      19.7      26.5
# 26267  51000      Jeollanam-do  2020-06-29      21.9      20.0      24.0
# 26268  60000  Gyeongsangbuk-do  2020-06-29      20.4      17.4      24.5
# 26269  61000  Gyeongsangnam-do  2020-06-29      21.9      18.8      25.5
# 26270  70000           Jeju-do  2020-06-29      23.2      19.1      27.6
#
#        precipitation  max_wind_speed  most_wind_direction  \
# ...

# %%
Time
# Out:
#            date  time     test  negative  confirmed  released  deceased
# 0    2020-01-20    16        1         0          1         0         0
# 1    2020-01-21    16        1         0          1         0         0
# 2    2020-01-22    16        4         3          1         0         0
# 3    2020-01-23    16       22        21          1         0         0
# 4    2020-01-24    16       27        25          2         0         0
# ..          ...   ...      ...       ...        ...       ...       ...
# 158  2020-06-26     0  1232315   1200885      12602     11172       282
# 159  2020-06-27     0  1243780   1211261      12653     11317       282
# 160  2020-06-28     0  1251695   1219975      12715     11364       282
# 161  2020-06-29     0  1259954   1228698      12757     11429       282
# 162  2020-06-30     0  1273766   1240157      12800     11537       282
#
# [163 rows x 7 columns]

# %%
Time=Time.loc[:161]
Time
# Out:
#            date  time     test  negative  confirmed  released  deceased
# 0    2020-01-20    16        1         0          1         0         0
# 1    2020-01-21    16        1         0          1         0         0
# 2    2020-01-22    16        4         3          1         0         0
# 3    2020-01-23    16       22        21          1         0         0
# 4    2020-01-24    16       27        25          2         0         0
# ..          ...   ...      ...       ...        ...       ...       ...
# 157  2020-06-25     0  1220478   1189015      12563     10974       282
# 158  2020-06-26     0  1232315   1200885      12602     11172       282
# 159  2020-06-27     0  1243780   1211261      12653     11317       282
# 160  2020-06-28     0  1251695   1219975      12715     11364       282
# 161  2020-06-29     0  1259954   1228698      12757     11429       282
#
# [162 rows x 7 columns]

# %%
plt.figure(figsize=(15,10))
plt.hist(Weather_covid["avg_temp"], bins=20,color='r', alpha=0.4)
plt.show()

# %% [markdown]
# ## 아이디어 7
# 서치트렌드와의 관계?

# %%
#날짜별 확진자 추이
df = SearchTrend


fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(df['date'],df['coronavirus'],color='blue')

plt.xticks(rotation=90)

plt.title('searchtrend over time',fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#날짜별 확진자 추이
df = Time


fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
ax = fig.add_subplot()

ax.plot(df['date'],df['confirmed'],color='blue')

plt.xticks(rotation=90)

plt.title('Number of confirmed cases over time',fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
